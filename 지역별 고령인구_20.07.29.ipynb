# %%
import pandas as pd
people2019 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2019.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
people2019
# Out:
#       기간    지역      전체인구   전체인구.1   전체인구.2 65세이상 인구 65세이상 인구.1 65세이상 인구.2  \
# 0     기간    지역      전체인구     전체인구     전체인구       합계         합계         합계
# 1     기간    지역         계       남자       여자        계         남자         여자
# 2   2019    합계  10010983  4877725  5133258  1485272     656595     828677
# 3   2019   종로구    161869    78215    83654    27519      12162      15357
# 4   2019    중구    136488    66823    69665    23275      10247      13028
# 5   2019   용산구    245185   119599   125586    38791      16466      22325
# 6   2019   성동구    308979   150861   158118    43947      19181      24766
# 7   2019   광진구    366972   176917   190055    47902      21360      26542
# 8   2019  동대문구    363023   178490   184533    59350      26397      32953
# 9   2019   중랑구    402024   199006   203018    65164      29136      36028
# 10  2019   성북구    454744   219099   235645    70850      30498      40352
# 11  2019   강북구    317695   154638   163057    60577      26032      34545
# ...

# %%
people2019.head()
# Out:
#      기간   지역      전체인구   전체인구.1   전체인구.2 65세이상 인구 65세이상 인구.1 65세이상 인구.2  \
# 0    기간   지역      전체인구     전체인구     전체인구       합계         합계         합계
# 1    기간   지역         계       남자       여자        계         남자         여자
# 2  2019   합계  10010983  4877725  5133258  1485272     656595     828677
# 3  2019  종로구    161869    78215    83654    27519      12162      15357
# 4  2019   중구    136488    66823    69665    23275      10247      13028
#
#   65세이상 인구.3 65세이상 인구.4 65세이상 인구.5 65세이상 인구.6 65세이상 인구.7 65세이상 인구.8
# 0        내국인        내국인        내국인      등록외국인      등록외국인      등록외국인
# 1          계         남자         여자          계         남자         여자
# 2    1478664     653108     825556       6608       3487       3121
# 3      27318      12049      15269        201        113         88
# 4      22974      10081      12893        301        166        135

# %%
old_people2019 = people2019.loc[0:2,['기간','전체인구','65세이상 인구']]
old_people2019
# Out:
#      기간      전체인구 65세이상 인구
# 0    기간      전체인구       합계
# 1    기간         계        계
# 2  2019  10010983  1485272

# %%
import pandas as pd
people2018 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2018.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2018 = people2018.loc[[2],['기간','전체인구','65세이상 인구']]
old_people2018
# Out:
#      기간      전체인구 65세이상 인구
# 2  2018  10049607  1416131

# %%
import pandas as pd
people2017 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2017.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2017 = people2017.loc[[2],['기간','전체인구','65세이상 인구']]
old_people2017
# Out:
#      기간      전체인구 65세이상 인구
# 2  2017  10124579  1365126

# %%
import pandas as pd
people2016 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2016.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2016 = people2016.loc[[2],['기간','전체인구','65세이상 인구']]
old_people2016
# Out:
#      기간      전체인구 65세이상 인구
# 2  2016  10204057  1300877

# %%
import pandas as pd
people2015 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2015.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2015 = people2015.loc[[2],['기간','전체인구','65세이상 인구']]
old_people2015

people2014 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2014.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2014 = people2014.loc[[2],['기간','전체인구','65세이상 인구']]

people2013 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2013.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2013 = people2013.loc[[2],['기간','전체인구','65세이상 인구']]

people2012 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2012.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2012 = people2012.loc[[2],['기간','전체인구','65세이상 인구']]

people2011 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2011.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2011 = people2011.loc[[2],['기간','전체인구','65세이상 인구']]

# %%
people2010 = pd.read_csv('data\\서울시 고령자현황 (동별) 통계 2010 - 구별로 합치기.txt', sep='\t',engine='python', encoding = 'UTF-8', thousands = ',')
old_people2010 = people2010.loc[[2],['기간','전체인구','65세이상 인구']]

# %%
peoplesum = pd.concat([old_people2019,old_people2018,old_people2017,old_people2016,old_people2015,old_people2014,old_people2013,old_people2012,old_people2011,old_people2010],axis=0)
peoplesum = peoplesum.drop([0,1])
peoplesum = peoplesum.set_index('기간')
peoplesum
# Out:
#           전체인구 65세이상 인구
# 기간
# 2019  10010983  1485272
# 2018  10049607  1416131
# 2017  10124579  1365126
# 2016  10204057  1300877
# 2015  10297138  1267563
# 2014  10369593  1221616
# 2013  10388055  1167177
# 2012  10442426  1110995
# 2011  10528774  1049425
# 2010  10575447  1002770

# %%
peoplesum = peoplesum.sort_index()

# %%
total = list(peoplesum['전체인구'])
total
# Out:
# ['10575447',
#  '10528774',
#  '10442426',
#  '10388055',
#  '10369593',
#  '10297138',
#  '10204057',
#  '10124579',
#  '10049607',
#  '10010983']

# %%
import matplotlib

matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

# %%
peoplesum['전체인구'] = peoplesum['전체인구'].astype('int')
peoplesum['65세이상 인구'] = peoplesum['65세이상 인구'].astype('int')

# %%
peoplesum['전체인구'].dtype
# Out:
# dtype('int32')

# %%
from matplotlib import pyplot as plt
import numpy as np
# plt.plot(peoplesum.index,peoplesum['전체인구'],peoplesum.index,peoplesum['65세이상 인구'],marker="o") 

barWidth = 0.4
idx = np.arange(len(peoplesum.index))
plt.bar(idx, peoplesum['전체인구'], align = 'edge' ,width= barWidth, color = 'c')
plt.bar(idx+barWidth, peoplesum['65세이상 인구'], align = 'edge', width = barWidth, color = 'b')
plt.xticks(idx + barWidth, peoplesum.index)

plt.xlabel('년도') 
plt.ylabel('인구 (만 명)') 
plt.title('총 인구 & 고령 인구 변화') 

plt.legend(['total', 'old'], loc='best') 
plt.savefig('data\\total_increase.png', dpi = 300)
plt.show()

# %% [markdown]
# # 열 추가하기

# %%
ratio = []

for i in range(len(old)):
    a = float(old[i].replace(',',''))
    b = float(total[i].replace(',',''))
    ratio.append(a/b)
    
print(ratio)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4ceae2fbfe3a> in <module>()
#       1 ratio = []
#       2
# ----> 3 for i in range(len(old)):
#       4     a = float(old[i].replace(',',''))
#       5     b = float(total[i].replace(',',''))
#
# NameError: name 'old' is not defined

# %%
peoplesum['노인비율'] = peoplesum['65세이상 인구'] / peoplesum['전체인구']
peoplesum

# %%
#peoplesum.plot(kind='barh')
plt.xlabel('년도') 
plt.ylabel('비율 (전체 인구 / 65세이상 인구 )') 
plt.title('총 인구 대비 노인 비율') 

plt.bar(peoplesum.index, peoplesum['노인비율'],color = 'c')

plt.savefig('data\\ratio_increase.png', dpi = 300)
plt.show()
