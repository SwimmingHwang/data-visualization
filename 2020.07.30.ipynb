# %%
! pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
# Requirement already satisfied: numpy in c:\users\hwang\anaconda3\lib\site-packages (from folium) (1.14.3)
# Requirement already satisfied: requests in c:\users\hwang\appdata\roaming\python\python36\site-packages (from folium) (2.19.1)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\hwang\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\hwang\appdata\roaming\python\python36\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\hwang\appdata\roaming\python\python36\site-packages (from requests->folium) (2.7)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\hwang\appdata\roaming\python\python36\site-packages (from requests->folium) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hwang\appdata\roaming\python\python36\site-packages (from requests->folium) (2018.4.16)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hwang\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0
# WARNING: You are using pip version 20.1; however, version 20.2 is available.
# You should consider upgrading via the 'c:\users\hwang\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import requests
import json
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import os
import webbrowser
import folium
from folium import plugins
print(folium.__version__)
# Out:
# 0.11.0

# %%
import pandas as pd
people2019 = pd.read_csv('data\\서울시 고령자현황 (구별) 통계 2019.txt', sep='\t', engine = 'python', encoding ='utf-8')
people2019
# Out:
#       기간    지역        전체인구     전체인구.1     전체인구.2   65세이상 인구 65세이상 인구.1  \
# 0     기간    지역        전체인구       전체인구       전체인구         합계         합계
# 1     기간    지역           계         남자         여자          계         남자
# 2   2019    합계  10,010,983  4,877,725  5,133,258  1,485,272    656,595
# 3   2019   종로구     161,869     78,215     83,654     27,519     12,162
# 4   2019    중구     136,488     66,823     69,665     23,275     10,247
# 5   2019   용산구     245,185    119,599    125,586     38,791     16,466
# 6   2019   성동구     308,979    150,861    158,118     43,947     19,181
# 7   2019   광진구     366,972    176,917    190,055     47,902     21,360
# 8   2019  동대문구     363,023    178,490    184,533     59,350     26,397
# 9   2019   중랑구     402,024    199,006    203,018     65,164     29,136
# 10  2019   성북구     454,744    219,099    235,645     70,850     30,498
# 11  2019   강북구     317,695    154,638    163,057     60,577     26,032
# 12  2019   도봉구     335,631    163,961    171,670     58,714     26,286
# 13  2019   노원구     537,303    259,810    277,493     80,923     34,024
# 14  2019   은평구     484,546    233,360    251,186     80,738     34,987
# 15  2019  서대문구     323,171    153,215    169,956     52,074     22,030
# 16  2019   마포구     385,925    181,303    204,622     52,429     21,954
# 17  2019   양천구     462,285    227,019    235,266     61,264     27,446
# 18  2019   강서구     598,273    289,691    308,582     84,077     37,157
# 19  2019   구로구     439,371    219,602    219,769     65,779     30,089
# 20  2019   금천구     251,820    128,954    122,866     37,660     17,184
# 21  2019  영등포구     400,986    200,986    200,000     57,872     26,142
# 22  2019   동작구     408,912    197,706    211,206     62,226     27,087
# 23  2019   관악구     517,334    259,194    258,140     75,194     33,591
# 24  2019   서초구     435,107    208,181    226,926     57,136     25,886
# 25  2019   강남구     550,209    263,345    286,864     71,025     31,935
# 26  2019   송파구     682,741    330,412    352,329     87,334     40,350
# 27  2019   강동구     440,390    217,338    223,052     63,452     28,968
#
#    65세이상 인구.2 65세이상 인구.3 65세이상 인구.4 65세이상 인구.5 65세이상 인구.6 65세이상 인구.7  \
# 0          합계        내국인        내국인        내국인      등록외국인      등록외국인
# 1          여자          계         남자         여자          계         남자
# 2     828,677  1,478,664    653,108    825,556      6,608      3,487
# 3      15,357     27,318     12,049     15,269        201        113
# 4      13,028     22,974     10,081     12,893        301        166
# 5      22,325     38,346     16,196     22,150        445        270
# 6      24,766     43,796     19,100     24,696        151         81
# 7      26,542     47,681     21,249     26,432        221        111
# 8      32,953     59,170     26,316     32,854        180         81
# 9      36,028     65,065     29,087     35,978         99         49
# 10     40,352     70,699     30,429     40,270        151         69
# 11     34,545     60,474     25,981     34,493        103         51
# 12     32,428     58,664     26,258     32,406         50         28
# 13     46,899     80,854     33,996     46,858         69         28
# 14     45,751     80,567     34,899     45,668        171         88
# 15     30,044     51,645     21,817     29,828        429        213
# 16     30,475     52,104     21,786     30,318        325        168
# 17     33,818     61,147     27,386     33,761        117         60
# 18     46,920     83,839     37,014     46,825        238        143
# 19     35,690     64,932     29,619     35,313        847        470
# 20     20,476     37,196     16,937     20,259        464        247
# 21     31,730     56,957     25,654     31,303        915        488
# 22     35,139     61,994     26,970     35,024        232        117
# 23     41,603     74,787     33,390     41,397        407        201
# 24     31,250     57,036     25,835     31,201        100         51
# 25     39,090     70,896     31,869     39,027        129         66
# 26     46,984     87,182     40,272     46,910        152         78
# 27     34,484     63,341     28,918     34,423        111         50
#
#    65세이상 인구.8
# 0       등록외국인
# 1          여자
# 2       3,121
# 3          88
# 4         135
# 5         175
# 6          70
# 7         110
# 8          99
# 9          50
# 10         82
# 11         52
# 12         22
# 13         41
# 14         83
# 15        216
# 16        157
# 17         57
# 18         95
# 19        377
# 20        217
# 21        427
# 22        115
# 23        206
# 24         49
# 25         63
# 26         74
# 27         61

# %%
old_people2019 = people2019.loc[:,['기간','지역','전체인구','65세이상 인구']]
old_people2019
# Out:
#       기간    지역        전체인구   65세이상 인구
# 0     기간    지역        전체인구         합계
# 1     기간    지역           계          계
# 2   2019    합계  10,010,983  1,485,272
# 3   2019   종로구     161,869     27,519
# 4   2019    중구     136,488     23,275
# 5   2019   용산구     245,185     38,791
# 6   2019   성동구     308,979     43,947
# 7   2019   광진구     366,972     47,902
# 8   2019  동대문구     363,023     59,350
# 9   2019   중랑구     402,024     65,164
# 10  2019   성북구     454,744     70,850
# 11  2019   강북구     317,695     60,577
# 12  2019   도봉구     335,631     58,714
# 13  2019   노원구     537,303     80,923
# 14  2019   은평구     484,546     80,738
# 15  2019  서대문구     323,171     52,074
# 16  2019   마포구     385,925     52,429
# 17  2019   양천구     462,285     61,264
# 18  2019   강서구     598,273     84,077
# 19  2019   구로구     439,371     65,779
# 20  2019   금천구     251,820     37,660
# 21  2019  영등포구     400,986     57,872
# 22  2019   동작구     408,912     62,226
# 23  2019   관악구     517,334     75,194
# 24  2019   서초구     435,107     57,136
# 25  2019   강남구     550,209     71,025
# 26  2019   송파구     682,741     87,334
# 27  2019   강동구     440,390     63,452

# %%
people_loc = old_people2019.drop([0,1])
people_loc
# Out:
#       기간    지역        전체인구   65세이상 인구
# 2   2019    합계  10,010,983  1,485,272
# 3   2019   종로구     161,869     27,519
# 4   2019    중구     136,488     23,275
# 5   2019   용산구     245,185     38,791
# 6   2019   성동구     308,979     43,947
# 7   2019   광진구     366,972     47,902
# 8   2019  동대문구     363,023     59,350
# 9   2019   중랑구     402,024     65,164
# 10  2019   성북구     454,744     70,850
# 11  2019   강북구     317,695     60,577
# 12  2019   도봉구     335,631     58,714
# 13  2019   노원구     537,303     80,923
# 14  2019   은평구     484,546     80,738
# 15  2019  서대문구     323,171     52,074
# 16  2019   마포구     385,925     52,429
# 17  2019   양천구     462,285     61,264
# 18  2019   강서구     598,273     84,077
# 19  2019   구로구     439,371     65,779
# 20  2019   금천구     251,820     37,660
# 21  2019  영등포구     400,986     57,872
# 22  2019   동작구     408,912     62,226
# 23  2019   관악구     517,334     75,194
# 24  2019   서초구     435,107     57,136
# 25  2019   강남구     550,209     71,025
# 26  2019   송파구     682,741     87,334
# 27  2019   강동구     440,390     63,452

# %%
state_geo = 'TL_SCCO_SIG_WGS84.json'
state_geo
# Out:
# 'TL_SCCO_SIG_WGS84.json'

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
people65 = people_loc.loc[:,['지역','65세이상 인구']]
people65 = people65.set_index('지역')
people65 = people65.drop('합계')

# %%
people65['65세이상 인구'] = people65['65세이상 인구'].str.replace(',','')
people65 = people65.astype({'65세이상 인구':int})

# %%
import json
geo_path = 'data\\02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                 tiles='Stamen Toner')
map.choropleth(geo_data = geo_str,
               data = people65['65세이상 인구'],
               columns = [people65.index, people65['65세이상 인구']],
               fill_color = 'PuRd', #puRd, YlGnBu
               key_on = 'feature.id')
# Out:
# C:\Users\Hwang\Anaconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
people65.dtypes
# Out:
# 65세이상 인구    int32
# dtype: object

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-eb2666483dcb> in <module>
#       4                fill_color = 'PuRd', #puRd, YlGnBu
#       5                key_on = 'feature.id')
# ----> 6 mmap = folium.Map(location[37.5102,126.982],zoom_start=12)
#       7 mmap
#
# NameError: name 'location' is not defined
